# %% [markdown]
# # Homework 2

# %%
from functools import reduce
import random
r = lambda x: random.randint(0, 99)
random.seed(0)

dicts = [{'a': 1, 'b': 2}, {'b': 3, 'c': 4}, {'a': 5, 'c': 6}]
# Add more dictionaries to the list
dicts.extend([{'d': r(0), 'e': r(0)}, {'e': r(0), 'f': r(0)}, {'f': r(0), 'g': r(0)}, {'g': r(0), 'h': r(0)}, {'h': r(0), 'i': r(0)}, {'i': r(0), 'j': r(0)}, {'j': r(0), 'k': r(0)}, {'k': r(0), 'l': r(0)}, {'l': r(0), 'm': r(0)}, {'m': r(0), 'n': r(0)}, {'n': r(0), 'o': r(0)}, {'o': r(0), 'p': r(0)}, {'p': r(0), 'q': r(0)}, {'q': r(0), 'r': r(0)}, {'r': r(0), 's': r(0)}, {'s': r(0), 't': r(0)}, {'t': r(0), 'u': r(0)}, {'u': r(0), 'v': r(0)}, {'v': r(0), 'w': r(0)}, {'w': r(0), 'x': r(0)}, {'x': r(0), 'y': r(0)}, {'y': r(0), 'z': r(0)}, {'z': r(0), 'a': r(0)}, {'a': r(0), 'b': r(0)}, {'b': r(0), 'c': r(0)}, {'c': r(0), 'd': r(0)}, {'d': r(0), 'e': r(0)}, {'e': r(0), 'f': r(0)}, {'f': r(0), 'g': r(0)}, {'g': r(0), 'h': r(0)}, {'h': r(0), 'i': r(0)}, {'i': r(0), 'j': r(0)}, {'j': r(0), 'k': r(0)}, {'k': r(0), 'l': r(0)}, {'l': r(0), 'm': r(0)}, {'m': r(0), 'n': r(0)}, {'n': r(0), 'o': r(0)}, {'o': r(0), 'p': r(0)}, {'p': r(0), 'q': r(0)}, {'q': r(0), 'r': r(0)}, {'r': r(0), 's': r(0)}, {'s': r(0), 't': r(0)}, {'t': r(0), 'u': r(0)}, {'u': r(0), 'v': r(0)}, {'v': r(0), 'w': r(0)}, {'w': r(0), 'x': r(0)}, {'x': r(0), 'y': r(0)}, {'y': r(0), 'z': r(0)}, {'z': r(0), '1': r(0)}, {'1': r(0), '2': r(0)}, {'2': r(0), '3': r(0)}, {'3': r(0), '4': r(0)}, {'4': r(0), '5': r(0)}, {'5': r(0), '6': r(0)}, {'6': r(0), '7': r(0)}, {'7': r(0), '8': r(0)}, {'8': r(0), '9': r(0)}, {'9': r(0), '0': r(0)}, {'0': r(0), 'a': r(0)}, {'a': r(0), 'b': r(0)}, {'b': r(0), 'c': r(0)}, {'c': r(0), 'd': r(0)}, {'d': r(0), 'e': r(0)}, {'e': r(0), 'f': r(0)}, {'f': r(0), 'g': r(0)}, {'g': r(0), 'h': r(0)}, {'h': r(0), 'i': r(0)}, {'i': r(0), 'j': r(0)}, {'j': r(0), 'k': r(0)}, {'k': r(0), 'l': r(0)}, {'l': r(0), 'm': r(0)}, {'m': r(0), 'n': r(0)}, {'n': r(0), 'o': r(0)}, {'o': r(0), 'p': r(0)}, {'p': r(0), 'q': r(0)}, {'q': r(0), 'r': r(0)}, {'r': r(0), 's': r(0)}, {'s': r(0), 't': r(0)}, {'t': r(0), 'u': r(0)}, {'u': r(0), 'v': r(0)}, {'v': r(0), 'w': r(0)}, {'w': r(0), 'x': r(0)}, {'x': r(0), 'y': r(0)}, {'y': r(0), 'z': r(0)}])


def merge_dicts(dicts):
    merged_dict = {}
    for d in dicts:
        for key, value in d.items():
            merged_dict[key] = merged_dict.get(key, 0) + value
    return merged_dict
    
merged_dict = merge_dicts(dicts)



reduce(lambda x, y: x+y, merged_dict.values()) / len(merged_dict)

dict(sorted(merged_dict.items(), key=lambda item: item[1]))
# Out:
# {'8': 14,
#  '5': 19,
#  '2': 27,
#  '7': 35,
#  '1': 47,
#  '4': 93,
#  'b': 118,
#  '0': 137,
#  '9': 158,
#  '3': 162,
#  'z': 181,
#  '6': 182,
#  'n': 194,
#  'c': 210,
#  'k': 215,
#  'q': 233,
#  'a': 240,
#  'm': 242,
#  'y': 242,
#  'p': 250,
#  't': 256,
#  'i': 259,
#  'r': 270,
#  'f': 271,
#  'v': 284,
#  'l': 295,
#  's': 302,
#  'j': 316,
#  'u': 321,
#  'g': 347,
#  'e': 357,
#  'w': 375,
#  'd': 385,
#  'x': 385,
#  'h': 394,
#  'o': 412}

# %%
tweets = [


 "Just finished training my neural network on a massive dataset. Accuracy skyrocketed! 🚀🤖 #MachineLearning #DeepLearning",


 "Exploring pandas for data manipulation. It's like having a Swiss Army knife for data! 🔍🐼 #Python #DataScience",


 "Visualizing complex data with matplotlib. The power of plots! 📊🎨 #DataViz #Python",


 "Spent hours debugging my code, only to find a missing semicolon. 😅 #CodingLife #Python #",


 "Feature engineering is an art. Transforming raw data into gold! ✨🔍 #FeatureEngineering #DataScience",


 "Just attended a fascinating webinar on Bayesian statistics. Mind officially blown! 🧠📈 #Statistics #DataScience",


 "When life gives you missing values, impute them! 💡🔍 #DataCleaning #Python #",


 "Deployed my first Flask app. Feeling like a wizard! 🧙‍♂️🌐 #Flask #WebDevelopment",


 "Data scientists be like: 'I've got 99 problems, but overfitting ain't one.' 😎🤓 #MachineLearningHumor",


 "Late-night coding session fueled by coffee and determination. ☕💻 #CodeLife #Python",


 "Data science is like solving a puzzle with missing pieces. 🧩🔍 #DataPuzzle #Analytics",


 "Pythonic code is my love language. 💙🐍 #Pythonic #Coding",


 "Exploring the hidden gems of NumPy. 🌟🔢 #NumPy #DataScience",


 "Regression models: When life gives you scattered points, draw a line! 📈🔍 #Regression #MachineLearning",


 "Data preprocessing: Where the magic happens before the magic happens. ✨🔍 #DataPreprocessing #ML",


 "SQL joins: Bringing tables together like a family reunion. 🍽️📊 #SQL #Databases",


 "Data visualization is the art of storytelling with numbers. 📊🎨 #DataStorytelling #Visualization",


 "K-means clustering: Grouping data like a VIP party organizer. 🎉🔍 #Clustering #UnsupervisedLearning",


 "Random forests: When decision trees join forces. 🌳🔍 #RandomForests #EnsembleLearning",


 "Support Vector Machines: The bodyguards of classification. 🤖🔍 #SVM #MachineLearning",


 "Principal Component Analysis: Reducing dimensions like a minimalist architect. 📏🔍 #PCA #DimensionalityReduction",


 "Gradient Descent: The downhill race to find the best model. 🏃‍♂️🔍 #GradientDescent #Optimization",


 "Data science ethics: Keeping algorithms on the straight and narrow. 🚦🔍 #Ethics #AI",


 "Big data: When your dataset needs its own zip code. 🌐🔍 #BigData #Analytics",


 "Hypothesis testing: Proving or disproving theories like a detective. 🔍🔬 #HypothesisTesting #Stats",


 "Cross-validation: Testing models like a strict teacher. 📝🔍 #CrossValidation #ML",


 "Natural Language Processing: Teaching computers to speak human. 🗣️🔍 #NLP #AI ####",


 "Feature selection: Picking the MVPs for your model. 🏀🔍 #FeatureSelection #ML",


 "Data science workflow: From raw data to actionable insights. 🔄🔍 #Workflow #Analytics",
 
"Bayesian networks: Connecting the dots with probabilities. 🧩🔍 #Bayesian #ProbabilisticModeling",


 "Data lakes: Where data swims freely. 🏊‍♂️🔍 #DataLakes #Storage",


 "A/B testing: Splitting audiences like a magician. 🎩🔍 #ABTesting #Experimentation",


 "Neural networks: Mimicking the brain, one layer at a time. 🧠🔍 #NeuralNetworks #DeepLearning",


 "Data science conferences: Where nerds unite! 🤓🔍 #Conferences #Networking",


 "Regression analysis: Predicting the future with math. #RegressionAnalysis #Stats",


 "Data storytelling: Turning numbers into narratives. 📖🔍 #Storytelling #DataViz",


 "Python libraries: My toolkit for world domination. 🛠️🐍 #PythonLibraries #Coding",


 "Just discovered a hidden correlation between coffee consumption and code quality. ☕🔍 #CaffeineDrivenCoding #DataScience",


 "Data scientists: The modern-day alchemists turning data into insights. 🔮🔍 #Alchemy #Analytics",


 "Python vs. R: The eternal battle of data science languages. 🐍🆚📊 #PythonVsR",


 "Data pipelines: Like building a highway for data to flow. 🛣️🔍 #DataPipelines #ETL",


 "Jupyter notebooks: Where ideas come to life, one cell at a time. 📝🔍 #Jupyter #Notebooks #1DatA",


 "Feature extraction: Unleashing the power of domain knowledge. ⚡🔍 #FeatureExtraction #ML",


 "Data science memes: Because laughter is the best regularization. 😂🔍 #DataScienceMemes",


 "SQL injections: When hackers try to drop tables, not beats. 🎤🔍 #SQLInjection #Security",


 "Data lakes vs. data warehouses: The battle of storage solutions. 🏞️🏢 #DataStorage #2Dat",


 "Ensemble methods: Combining models like a musical ensemble. 🎵🔍 #EnsembleMethods #ML ###",


 "Exploratory data analysis: Where data scientists become detectives. 🔍🕵️‍♂️ #EDA #DataScience",


 "Kaggle competitions: The Olympics of data science. 🏆🔍 #Kaggle #Competitions",


 "Regularization: Keeping models in check like a strict teacher. 📏🔍 #Regularization #ML",


 "Data science interviews: Solving puzzles under pressure. 🧩🔍 #InterviewPrep #TechJobs",


 "Data ethics: Because algorithms have feelings too (just kidding). 🤖❌ #EthicalAI #DataScience",


 "Deep learning: When neural networks go deep, not shallow. 🌊🔍 #DeepLearning #NeuralNetworks",


 "Data science conferences: Where swag bags are filled with pandas and numpy stickers. 🐼🔍 #SwagLife",


 "Bayesian vs. frequentist statistics: The ultimate showdown. 🤺🔍 #BayesianVsFrequentist",


 "Data visualization libraries: Plotting the course to insights. 📈🔍 #DataVizLibraries",


 "Data augmentation: Making your dataset more interesting than your last vacation. 📸🔍 #DataAugmentation",


 "A/B testing: Splitting users like a deck of cards. ♠️♣️ #ABTesting #Experimentation",


 "Data science bootcamps: Where novices become ninjas. 🥋🔍 #Bootcamps #Learning",


 "Neural architecture search: Finding the perfect brain for your AI. 🧠🔍 #NAS ##AI",


 "Data science blogs: Where knowledge flows like data through a pipeline. 📰🔍 #Blogging",


 "Data storytelling: Turning numbers into poetry. 📊📝 #DatAPoetry # 1 #BIGdata",


 "Data science meetups: Where introverts network like extroverts. 🤝🔍 #Meetups #Networking #2024",


 "Data preprocessing: Untangling messy data like a patient hairdresser. 💇‍♀️🔍 #DataPrep",


 "Data science challenges: Solving puzzles with a side of adrenaline. 🧩🔍 #Challenges",


 "Natural language understanding: Teaching machines to read between the lines. 📖🔍 #NLU",


 "Data science podcasts: Because sometimes your eyes need a break. 🎧🔍 #Podcasts",


 "Data science mentors: Gandalfs guiding Frodos through the analytics journey. 🧙‍♂️🔍 #Mentorship",


 "Data science job titles: From data wranglers to machine whisperers. 🤖🔍 #JobTitles",


 "Data science life cycle: From data inception to model retirement. ♻️🔍 #LifeCycle #1",


 "Data science conferences: Where nerds unite! 🤓🔍 #Conferences #Networking",


 "Regression analysis: Predicting the future with math. 🔮🔍 #RegressionAnalysis #Stats #Ece",


 "Data storytelling: Turning numbers into narratives. 📖🔍 #Storytelling #DataViz #ECE",


 "Python libraries: My toolkit for world domination. 🛠️🐍 #PythonLibraries #Coding ## "
]
import re
matches = []

for str in tweets:
    match = re.findall(r"\B(\#[a-zA-Z\d]+\b)", str)
    for tag in match:
       matches.append(tag)

matches = list(set(matches))

data = []
for match in matches: 
    if "data" in match or "Data" in match:
        data.append(match)
data
# Out:
# ['#DataAugmentation',
#  '#DataPreprocessing',
#  '#Databases',
#  '#DataScienceMemes',
#  '#DataStorage',
#  '#DataPipelines',
#  '#DataScience',
#  '#DataPuzzle',
#  '#DataLakes',
#  '#DataViz',
#  '#DataCleaning',
#  '#BIGdata',
#  '#BigData',
#  '#DataVizLibraries',
#  '#DataPrep',
#  '#DataStorytelling']

# %%
p1 = ("""Strings are sequences of characters that can represent various types of data, """
      """such as text, symbols, or numbers. In data science, strings are important for many reasons, as they can be used for """
      """different purposes and applications. One of the main uses of strings is to store and manipulate textual data, such as names, addresses, """
      """tweets, reviews, articles, books, etc. Textual data can provide valuable insights into human behavior, preferences, opinions, emotions, etc. Strings """
      """can also be used to encode categorical variables, such as gender, color, or class labels. Categorical variables are """
      """discrete and nominal, and they can be used to group or classify data points based on some criteria. Strings can be converted """
      """to numerical values using various methods, such as hashing, encoding, or embedding. Hashing is a technique that maps strings to """
      """integers using a hash function. Encoding is a technique that assigns a unique integer to each string value. Embedding is a technique """
      """that transforms strings into vectors of real numbers using a neural network. Strings can also be analyzed using natural language """
      """processing techniques, such as tokenization, stemming, lemmatization, sentiment analysis, topic modeling, etc. Tokenization is a technique """
      """that splits strings into smaller units, such as words, characters, or n-grams. Stemming is a technique that reduces words to their root forms, such """
      """as 'running' to 'run'. Lemmatization is a technique that converts words to their canonical forms, such as 'is' to 'be'. Sentiment analysis is a technique """
      """that determines the polarity and emotion of a text, such as positive, negative, or neutral. Topic modeling is a technique that identifies the main themes or """
      """topics of a text, such as sports, politics, or entertainment. Strings can also be used to generate new content, such as summaries, captions, headlines, stories, """
      """poems, etc. Summarization is a technique that creates a concise and informative representation of a longer text. Captioning is a technique that generates a descriptive """
      """text for an image or a video. Headline generation is a technique that produces a catchy and relevant title for a text. Story and poem generation are techniques that create creative and coherent texts based on some prompts or constraints. Strings are versatile and powerful tools for data science, and they can be defined as python strings using single or double quotes, such as 'hello' or "world".""")
p2 = ("""Strings are sequences of characters that can represent various types of data, such as text, symbols, or numbers. In data """
    """science, strings are important for many reasons, as they can be used for different purposes and applications. One of the main uses of strings """
    """is to store and manipulate textual data, such as names, addresses, tweets, reviews, articles, books, etc. Textual data can provide valuable insights """
    """into human behavior, preferences, opinions, emotions, etc. Strings can also be used to encode categorical variables, such as gender, color, or class """
    """labels. Categorical variables are discrete and nominal, and they can be used to group or classify data points based on some criteria. """
    """Strings can be converted to numerical values using various methods, such as hashing, encoding, or embedding. Harsing is a """
    """technique that maps strings to integers using a hash function. Encoding is a technique that assigns a unique integer to each string """
    """value. Embedding is a technique that transforms strings into vetcors of real numbers using a neural network. Strings can also be analyzed """
    """using natural language processing techniques, such as tokenization, stemming, lemmatization, sentiment analysis, topic modeling, etc. """
    """Tokenization is a technique that splits strings into smaller units, such as words, characters, or n-grams. Stemming is a technique that """
    """reduces words to their root forms, such as 'running' to 'run'. Lemmatization is a technique that converts words to their canonical """
    """forms, such as 'is' to 'be'. Sentiment analysis is a technique that determines the polarity and emotion of a text, such as positive, """
    """negative, or nuetral. Topic modeling is a technique that identifeis the main themes or topics of a text, such as sports, politics, or entertainment. Strings can also be used to generate new content, such as summaries, captions, headlines, stories, poems, etc. Summarization is a technique that creates a concise and informative representation of a longer text. Captioning is a technique that generates a descriptive text for an image or a video. Haedline generation is a technique that produces a catchy and relevant title for a text. Story and poem generation are techniques that create craetive and coherent texts based on some prompts or constraints. Strings are versatile and powerful tools for data sceince, and they can be defined as python strings using single or double quotes, such as 'hello' or "world".""")

def d(str1, str2):

    diff_count = sum(map(lambda x: 1 if x[0] != x[1] else 0, zip(str1, str2)))
    return diff_count


d(p1, p2)
# Out:
# 14

# %%
text = """Data Science is the interdisciplinary field. One of the key aspects is the ability to analyse large datasets, often referred to as big data. Big data can be characterised by the four Vs: volume, variety, velocity, and veracity, which can be utilised. Volume refers to the sheer amount of data that is available, which can range from terabytes to zettabytes. Variety refers to the different types and sources of data, such as structured, unstructured, or semi-structured data, and text, images, audio, video, or sensor data. Velocity refers to the speed at which data is generated, which can be real-time, near-real-time, or batch. Veracity refers to the quality and reliability of data, which can be affected by errors, incompleteness, or inconsistency.

The abundance of data in the future will create both opportunities and challenges for Data Science. On one hand, it will enable us to discover new patterns, trends, and correlations, and to develop more accurate and robust models and algorithms. On the other hand, it will require us to develop new methods and techniques to deal with the complexity, diversity, and uncertainty of data, and to ensure the ethical, legal, and social implications of data analysis. Data Science will also need to adapt to the changing needs and expectations of the users and stakeholders, and to communicate the results and implications of data analysis effectively and responsibly.

Data Science is a dynamic and evolving field that requires constant learning and innovation. Data Science is also a collaborative and interdisciplinary field that benefits from the exchange of ideas and perspectives from different domains and disciplines. Data Science is not only a technical skill, but also a way of thinking and a mindset that values curiosity, creativity, and critical thinking. Data Science is a powerful tool that can help us understand of the world and shape the future."""



def convert(str):
    str = re.sub("se ","ze ",str)
    str = re.sub("sed","zed",str)
    return str

text1 = convert(text)
d(text1,text)
# Out:
# 3

# %% [markdown]
# ### Note

# %% [markdown]
# This homework will be focused on visualizing relationships between variables for plotting. It will provide a dataset, then ask to a question about the relationship between two variables. An example question might be
#
# > What statements are true about the relationship between variables A and B?
# >
# > 1. Higher A tends to mean higher B
# > 2. Lower A tends to mean higher B
# > 3. There's no clear relationship between A and B
# > 4. Every B variable is greater than 2
#
# The DataFrame that provides variables `A` and `B` will be provided, and will be encoded in a column of the DataFrame. Plotting variables `A` and `B` might yield
#
# <img src="./example.png" width="400px" />
#
# Statements (1) and (4) would be true given this plot.

# %% [markdown]
# ---

# %% [markdown]
# **Problem 1.**
# Use the code below to obtain the Flights data set. It contains information about distance traveled by the flights and delay in their arrival.
#
# ```python
# df1 = pd.read_csv("flights_20k.csv")
# ```
# You might observe that some flights have a negative delay. In this question, our objective is to analyze the relationship between the `distance` and `delay` variables for all flights that arrived early (i.e. **delay < 0**).
#
# Here is a hint:
# 1. Obtain a dataframe that contains all records with a negative delay (< 0).
# 2. Plot the `distance` and `delay` variables which represent the distance traveled by the flight and the delay in arrival to the destination.
#
# Which of the statements would hold for the plot obtained?
#
# A. There is a rough tendency that flights that travel a longer distance tend to arrive **later** (less negative delay).
#
# B. There is a rough tendency that flights that travel a longer distance tend to arrive **earlier** (more negative delay).
#
#
# <br>
#
# **`Gold-Star Question`**: Think about what kind of plot is apt for this data. Does switching the x-axis and y-axis variable affect your conclusion?

# %%
import pandas as pd
df1 = pd.read_csv("flights_20k.csv")
df1.head(3)
# Out:
#                   date  delay destination  distance origin
# 0  2001-01-13 14:56:00     32         SJC       417    SAN
# 1  2001-01-31 16:40:00     -5         ISP      1093    FLL
# 2  2001-02-11 18:39:00      3         DAL       293    LBB

# %%
# your code here
df2 = df1[df1["delay"] < 0]

df2.plot.scatter(x = "distance", y = "delay",ylim=[-50, 0])
# Out:
# <Axes: xlabel='distance', ylabel='delay'>

# %% [markdown]
# ---

# %% [markdown]
# **Problem 2.** Consider the movies data set obtained from the code below. It contains various features of a movie, like its IMDB rating, Run-time, US Gross, Worldwide Gross, etc.
#
# ```python
# df2 = pd.read_csv("movies.csv")
# ```
# Which of the following claims are true about the data. Check all that apply
#
# **Options**
#
# A. Plotting a histogram of the Production Budget of **all** movies reveals a skewed right distribution. (Use `bins=15` while plotting) <br>
#
# B. A few movies that have a higher US Gross have a high IMDB Rating as well. But there are plenty of movies that have been rated high in IMDB without actually grossing a lot, so the trend is not very clear. <br>
#
# C. IMDB and Rotten Tomatoes ratings do not seem to have any relation between them <br>
#
# D. Most movies that have a higher Rotten Tomatoes rating tend to have a higher IMDB rating as well. <br>

# %%
# Given code
df2 = pd.read_csv("movies.csv")
df2.head()
# Out:
#           Creative_Type Director Distributor  IMDB_Rating  IMDB_Votes  \
# 0                   NaN      NaN    Gramercy          6.1      1071.0
# 1                   NaN      NaN      Strand          6.9       207.0
# 2                   NaN      NaN   Lionsgate          6.8       865.0
# 3                   NaN      NaN   Fine Line          NaN         NaN
# 4  Contemporary Fiction      NaN     Trimark          3.4       165.0
#
#   MPAA_Rating Major_Genre  Production_Budget Release_Date  \
# 0           R         NaN          8000000.0    12-Jun-98
# 1           R       Drama           300000.0     7-Aug-98
# 2         NaN      Comedy           250000.0    28-Aug-98
# 3         NaN      Comedy           300000.0    11-Sep-98
# 4           R       Drama          1000000.0     9-Oct-98
#
#    Rotten_Tomatoes_Rating  Running_Time_min               Source  \
# 0                     NaN               NaN                  NaN
# ...

# %%
# your code here
df2.plot.scatter(x = "IMDB_Rating", y = "Rotten_Tomatoes_Rating")
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Rotten_Tomatoes_Rating'>

# %%
df2.plot.scatter(x = "IMDB_Rating", y = "US_Gross")
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='US_Gross'>

# %%
df2["Production_Budget"].plot.hist(bins=15, ec='black')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ---

# %% [markdown]
# **Problem 3.** Consider the Gapminder data set obtained from the code below. It contains information such as life expectancy, fertility rate (Children per woman), population etc. about countries over the years.
# ```python
# df3 = pd.read_csv("gapminder.csv")
# ```
# Which of the following is True?
#
# **Options**
#
# A - Life expectancy and fertility have a positive trend between them. This means that as as one increases, the other tends to increase too.
#
# B - Life expectancy and fertility have a negative trend between them. This means that as one increases, the other tends to decrease.
#
# C - Plot the population of Rwanda over the years. There is a sudden dip in the population of Rwanda around mid 1990's.
#
# D - Plot the population of Kenya over the years. There is a sudden dip in the population of Kenya around mid 1990's.
#
# **`Gold-Star Question`**:  At-least one of the observations about Kenya and Rwanda is true. What unfortunate event could have caused this?

# %%
# given code
df3 = pd.read_csv("gapminder.csv")
df3.head()
# Out:
#    cluster      country  fertility  life_expect       pop  year
# 0        0  Afghanistan        7.7       30.332   8891209  1955
# 1        0  Afghanistan        7.7       31.997   9829450  1960
# 2        0  Afghanistan        7.7       34.020  10997885  1965
# 3        0  Afghanistan        7.7       36.088  12430623  1970
# 4        0  Afghanistan        7.7       38.438  14132019  1975

# %%
# your code here
df3.plot.scatter(x = "fertility", y = "life_expect")
# Out:
# <Axes: xlabel='fertility', ylabel='life_expect'>

# %%
df3[df3["country"] == "Kenya"].plot.line(x = "year", y = "pop")
# Out:
# <Axes: xlabel='year'>

# %%
df3[df3["country"] == "Rwanda"].plot.line(x = "year", y = "pop")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ---
# **Problem 4.**
# Consider the cars data set imported using the code below, containing information about different cars built over the years.
# ```python
# df4 = pd.read_csv("cars.csv")
# ```
# What inference can you derive from the data?
#
# **Options**
#
# A - Cars with higher Horsepower tend to have higher Displacement.
#
# B - Cars with lower Horsepower tend to have higher Displacement.
#
# C - Heavier cars tend to have a lower Mileage (Miles_per_Gallon)
#
# D - Cars with more cylinders tend to have lower horsepower

# %%
# given code
df4 = pd.read_csv("cars.csv")
df4.head()
# Out:
#    Unnamed: 0  Acceleration  Cylinders  Displacement  Horsepower  \
# 0           0          12.0          8         307.0       130.0
# 1           1          11.5          8         350.0       165.0
# 2           2          11.0          8         318.0       150.0
# 3           3          12.0          8         304.0       150.0
# 4           4          10.5          8         302.0       140.0
#
#    Miles_per_Gallon                       Name Origin  Weight_in_lbs  \
# 0              18.0  chevrolet chevelle malibu    USA           3504
# 1              15.0          buick skylark 320    USA           3693
# 2              18.0         plymouth satellite    USA           3436
# 3              16.0              amc rebel sst    USA           3433
# 4              17.0                ford torino    USA           3449
#
#          Year
# 0  1970-01-01
# 1  1970-01-01
# 2  1970-01-01
# 3  1970-01-01
# 4  1970-01-01

# %%
# your code here
df4.plot.scatter(x = "Horsepower", y = "Displacement")
# Out:
# <Axes: xlabel='Horsepower', ylabel='Displacement'>

# %%
df4.plot.scatter(x = "Cylinders", y = "Horsepower")
# Out:
# <Axes: xlabel='Cylinders', ylabel='Horsepower'>

# %%
df4.plot.scatter(x = "Weight_in_lbs", y = "Miles_per_Gallon")
# Out:
# <Axes: xlabel='Weight_in_lbs', ylabel='Miles_per_Gallon'>

# %% [markdown]
# ---
# **Problem 5.** Consider the Stocks data imported from the code below. It shows monthly prices of 5 companies over time.
# ```python
# df5 = pd.read_csv("stocks.csv")
# ```
# Which of the following statements are true about the data -
#
# Hints:
#
# To get more ticks in the x axis than default, you can use the following code. We an decrease/increase the step value to get more/less granular x-ticks respectively. (We are taking the range between 0-124 because we only have 123 data points)
# ```python
# ax.set_xticks(range(0, 124, 5));
# ```
# You will not be able to get dates in the x-ticks , but you can find the date for a particular index by pandas indexing.
#
# **Options**
#
# A - There is an overall **decrease** in all stock prices in the dataframe index range 100 - 110.
#
# B - There is an overall **decrease** in all stock prices between dates May-2008 to March-2009.
#
# C - All stock prices fall in the in the dataframe index range 55- 60.
#
# D - In a line plot, Google has no price until index 55 because values before index 55 are zero.
#
# E - In a line plot, Google has no price until index 55 because values before index 55 are nan.

# %%
# given code
df5 = pd.read_csv("stocks.csv")
df5
# Out:
#            date   Apple  Amazon  Google     IBM  Microsoft
# 0    2000-01-01   25.94   64.56     NaN  100.52      39.81
# 1    2000-02-01   28.66   68.87     NaN   92.11      36.35
# 2    2000-03-01   33.95   67.00     NaN  106.11      43.22
# 3    2000-04-01   31.01   55.19     NaN   99.95      28.37
# 4    2000-05-01   21.00   48.31     NaN   96.31      25.45
# ..          ...     ...     ...     ...     ...        ...
# 118  2009-11-01  199.91  135.91  583.00  125.79      29.27
# 119  2009-12-01  210.73  134.52  619.98  130.32      30.34
# 120  2010-01-01  192.06  125.41  529.94  121.85      28.05
# 121  2010-02-01  204.62  118.40  526.80  127.16      28.67
# 122  2010-03-01  223.02  128.82  560.19  125.55      28.80
#
# [123 rows x 6 columns]

# %%
# your code here
df6 = df5.iloc[98:111]
ax = df6.plot.line(x = "date",rot=15)
df6
# Out:
#            date   Apple  Amazon  Google     IBM  Microsoft
# 98   2008-03-01  143.50   71.30  440.47  110.87      27.21
# 99   2008-04-01  173.95   78.63  574.29  116.23      27.34
# 100  2008-05-01  188.75   81.62  585.80  125.14      27.25
# 101  2008-06-01  167.44   73.33  526.42  114.60      26.47
# 102  2008-07-01  158.95   76.34  473.75  123.74      24.75
# 103  2008-08-01  169.53   80.81  463.29  118.16      26.36
# 104  2008-09-01  113.66   72.76  400.52  113.53      25.78
# 105  2008-10-01  107.59   57.24  359.36   90.24      21.57
# 106  2008-11-01   92.67   42.70  292.96   79.65      19.66
# 107  2008-12-01   85.35   51.28  307.65   82.15      18.91
# 108  2009-01-01   90.13   58.82  338.53   89.46      16.63
# 109  2009-02-01   89.31   64.79  337.99   90.32      15.81
# 110  2009-03-01  105.12   73.44  348.06   95.09      17.99

# %%
df6 = df5.iloc[55:61]
ax = df6.plot.line(x = "date",rot=15)
ax
# Out:
# <Axes: xlabel='date'>

# %%
df6 = df5.iloc[100:111]
ax = df6.plot.line(x = "date",rot=15)
df6
# Out:
#            date   Apple  Amazon  Google     IBM  Microsoft
# 100  2008-05-01  188.75   81.62  585.80  125.14      27.25
# 101  2008-06-01  167.44   73.33  526.42  114.60      26.47
# 102  2008-07-01  158.95   76.34  473.75  123.74      24.75
# 103  2008-08-01  169.53   80.81  463.29  118.16      26.36
# 104  2008-09-01  113.66   72.76  400.52  113.53      25.78
# 105  2008-10-01  107.59   57.24  359.36   90.24      21.57
# 106  2008-11-01   92.67   42.70  292.96   79.65      19.66
# 107  2008-12-01   85.35   51.28  307.65   82.15      18.91
# 108  2009-01-01   90.13   58.82  338.53   89.46      16.63
# 109  2009-02-01   89.31   64.79  337.99   90.32      15.81
# 110  2009-03-01  105.12   73.44  348.06   95.09      17.99

# %%
df5.iloc[50:60]
# Out:
#           date  Apple  Amazon  Google    IBM  Microsoft
# 50  2004-03-01  13.52   43.28     NaN  84.41      20.46
# 51  2004-04-01  12.89   43.60     NaN  81.04      21.45
# 52  2004-05-01  14.03   48.50     NaN  81.59      21.53
# 53  2004-06-01  16.27   54.40     NaN  81.19      23.44
# 54  2004-07-01  16.17   38.92     NaN  80.19      23.38
# 55  2004-08-01  17.25   38.14  102.37  78.17      22.47
# 56  2004-09-01  19.38   40.86  129.60  79.13      22.76
# 57  2004-10-01  26.20   34.13  190.64  82.84      23.02
# 58  2004-11-01  33.53   39.68  181.98  87.15      24.60
# 59  2004-12-01  32.20   44.29  192.79  91.16      24.52

# %% [markdown]
# ---
